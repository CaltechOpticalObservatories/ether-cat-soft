# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
from helpers.position_camera_helpers import *
# %matplotlib inline

# %%
cap = open_webcam(1)
frame = get_frame(cap)
plt.imshow(frame)
plt.show()

# %%
top_line, bottom_line = get_top_and_bottom_lines(frame)

# %%
correlation = correlate_1d_arrays(top_line[0], bottom_line[0])
plt.plot(correlation)
plt.show()

# %%
cap = open_webcam(1)
frame = get_frame(cap)
plt.imshow(frame)
plt.show()

# %%
top_line, bottom_line = get_top_and_bottom_lines(frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 top_line, bottom_line = get_top_and_bottom_lines(frame)
#
# NameError: name 'get_top_and_bottom_lines' is not defined

# %%
correlation = correlate_1d_arrays(top_line[0], bottom_line[0])
plt.plot(correlation)
plt.show()

# %%
find_offset_in_um(correlation, 10)
# Out:
# 145.0

# %%
top_line_upscaled = upscale_and_gaussian_blur_1d_array(top_line[0], 10, 10)
bottom_line_upscaled = upscale_and_gaussian_blur_1d_array(bottom_line[0], 10, 10)

upscaled_correlation = correlate_1d_arrays(top_line_upscaled, bottom_line_upscaled)
plt.plot(upscaled_correlation)
plt.show()

print(find_offset_in_um(upscaled_correlation, 10/10))
# Out:
# 145.5
